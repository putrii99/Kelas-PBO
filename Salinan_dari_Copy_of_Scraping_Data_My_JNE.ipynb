# %% [markdown]
# <a href="https://colab.research.google.com/github/putrii99/Kelas_PBO/blob/master/Salinan_dari_Copy_of_Scraping_Data_My_JNE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app

# %%
from google_play_scraper import Sort, reviews_all

id_reviews = reviews_all(
    'com.indivara.jneone',
    sleep_milliseconds=0, # defaults to 0
    lang='in', # defaults to 'in'
    country='id', # defaults to 'id'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
)

# %%
df_busu = pd.DataFrame(np.array(id_reviews),columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head(15000)
# Out:
#                                    reviewId         userName  \
# 0      5964e85d-de08-4186-bc51-c9e6b168bb8f       Bapak Jali
# 1      ecf5f35a-ff8a-4541-a656-9ea7f925c805    Rahmat Riyadi
# 2      7912fad1-f31a-4efb-b5f8-6043f5b53786  Marsono Marsono
# 3      c38a532d-c50b-4238-ba58-0d103a80c6be         Omah Pvc
# 4      e73d2367-1891-4961-9010-0e09a3d5deab     Tiktok Viral
# ...                                     ...              ...
# 14995  950b2373-28e7-48ff-b627-776db280975c       Raff Sujie
# 14996  6db0511a-c3a2-47e6-8375-7a8e88936c7d        wahda nia
# 14997  18f23fe8-75b4-4d1a-9e30-3aefa966a21c      Aldi Pirman
# 14998  1900d2d6-1f80-46e1-affa-ec3d05b3193f    Dewi Aniviria
# 14999  77699257-53be-4a73-9eae-559dadf319ff      Yesi Farhan
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/AGNmyx...
# 1      https://play-lh.googleusercontent.com/a-/ACB-R...
# 2      https://play-lh.googleusercontent.com/a/AGNmyx...
# ...
